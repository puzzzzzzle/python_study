# %%
source = """
PI = 3.14

def circle_area(r):
    return PI * r ** 2

class Dog(object):

    def __init__(self, name):
        self.name = name

    def yelp(self):
        print('woof, i am', self.name)
"""
code = compile(source, filename="<string>", mode="exec")
print(code)
# Out:
# <code object <module> at 0x7f0e3fd49c50, file "<string>", line 1>

# %%
print(code.co_code)
print(code.co_consts)
print(code.co_names)
print(code.co_varnames)
print(code.co_filename)
print(code.co_firstlineno)
print(code.co_lnotab)
print(code.co_freevars)
print(code.co_cellvars)
# Out:
# b'\x97\x00d\x00Z\x00d\x01\x84\x00Z\x01\x02\x00G\x00d\x02\x84\x00d\x03e\x02\xa6\x03\x00\x00\xab\x03\x00\x00\x00\x00\x00\x00\x00\x00Z\x03d\x04S\x00'
# (3.14, <code object circle_area at 0x7f0e3fc91b50, file "<string>", line 4>, <code object Dog at 0x7f0e3fc91ed0, file "<string>", line 7>, 'Dog', None)
# ('PI', 'circle_area', 'object', 'Dog')
# ()
# <string>
# 1
# b'\x00\xff\x02\x02\x04\x02\x06\x03'
# ()
# ()

# %%
dog_code = code.co_consts[2]
print(dog_code)
print(dog_code.co_consts)
# Out:
# <code object Dog at 0x7f0e3fc91ed0, file "<string>", line 7>
# ('Dog', <code object __init__ at 0x7f0e5473d550, file "<string>", line 9>, <code object yelp at 0x7f0e3fd49980, file "<string>", line 12>, None)

# %%
import dis

dis.dis(code)
# Out:
#   0           0 RESUME                   0
#
#   2           2 LOAD_CONST               0 (3.14)
#               4 STORE_NAME               0 (PI)
#
#   4           6 LOAD_CONST               1 (<code object circle_area at 0x7f0e3fc91b50, file "<string>", line 4>)
#               8 MAKE_FUNCTION            0
#              10 STORE_NAME               1 (circle_area)
#
#   7          12 PUSH_NULL
#              14 LOAD_BUILD_CLASS
#              16 LOAD_CONST               2 (<code object Dog at 0x7f0e3fc91ed0, file "<string>", line 7>)
#              18 MAKE_FUNCTION            0
#              20 LOAD_CONST               3 ('Dog')
#              22 LOAD_NAME                2 (object)
#              24 PRECALL                  3
#              28 CALL                     3
#              38 STORE_NAME               3 (Dog)
#              40 LOAD_CONST               4 (None)
#              42 RETURN_VALUE
#
# Disassembly of <code object circle_area at 0x7f0e3fc91b50, file "<string>", line 4>:
#   4           0 RESUME                   0
#
#   5           2 LOAD_GLOBAL              0 (PI)
#              14 LOAD_FAST                0 (r)
#              16 LOAD_CONST               1 (2)
#              18 BINARY_OP                8 (**)
#              22 BINARY_OP                5 (*)
#              26 RETURN_VALUE
#
# Disassembly of <code object Dog at 0x7f0e3fc91ed0, file "<string>", line 7>:
#   7           0 RESUME                   0
#               2 LOAD_NAME                0 (__name__)
#               4 STORE_NAME               1 (__module__)
#               6 LOAD_CONST               0 ('Dog')
#               8 STORE_NAME               2 (__qualname__)
#
#   9          10 LOAD_CONST               1 (<code object __init__ at 0x7f0e5473d550, file "<string>", line 9>)
#              12 MAKE_FUNCTION            0
#              14 STORE_NAME               3 (__init__)
#
#  12          16 LOAD_CONST               2 (<code object yelp at 0x7f0e3fd49980, file "<string>", line 12>)
#              18 MAKE_FUNCTION            0
#              20 STORE_NAME               4 (yelp)
#              22 LOAD_CONST               3 (None)
#              24 RETURN_VALUE
#
# Disassembly of <code object __init__ at 0x7f0e5473d550, file "<string>", line 9>:
#   9           0 RESUME                   0
#
#  10           2 LOAD_FAST                1 (name)
#               4 LOAD_FAST                0 (self)
#               6 STORE_ATTR               0 (name)
#              16 LOAD_CONST               0 (None)
#              18 RETURN_VALUE
#
# Disassembly of <code object yelp at 0x7f0e3fd49980, file "<string>", line 12>:
#  12           0 RESUME                   0
#
#  13           2 LOAD_GLOBAL              1 (NULL + print)
#              14 LOAD_CONST               1 ('woof, i am')
#              16 LOAD_FAST                0 (self)
#              18 LOAD_ATTR                1 (name)
#              28 PRECALL                  2
#              32 CALL                     2
#              42 POP_TOP
#              44 LOAD_CONST               0 (None)
#              46 RETURN_VALUE

# %%
code = """
import sys as s
"""
code = compile(code, filename="<string>", mode="exec")
print(code.co_consts)
print(code.co_names)
dis.dis(code)
# Out:
# (0, None)
# ('sys', 's')
#   0           0 RESUME                   0
#
#   2           2 LOAD_CONST               0 (0)
#               4 LOAD_CONST               1 (None)
#               6 IMPORT_NAME              0 (sys)
#               8 STORE_NAME               1 (s)
#              10 LOAD_CONST               1 (None)
#              12 RETURN_VALUE

# %%
code = """
pi = 3.14
def circle_area(r):
    return pi * r ** 2

circle_area(2)
"""
code = compile(code, filename="<string>", mode="exec")
print(code.co_consts)
print(code.co_names)
dis.dis(code)
# Out:
# (3.14, <code object circle_area at 0x7f0e3fc91d10, file "<string>", line 3>, 2, None)
# ('pi', 'circle_area')
#   0           0 RESUME                   0
#
#   2           2 LOAD_CONST               0 (3.14)
#               4 STORE_NAME               0 (pi)
#
#   3           6 LOAD_CONST               1 (<code object circle_area at 0x7f0e3fc91d10, file "<string>", line 3>)
#               8 MAKE_FUNCTION            0
#              10 STORE_NAME               1 (circle_area)
#
#   6          12 PUSH_NULL
#              14 LOAD_NAME                1 (circle_area)
#              16 LOAD_CONST               2 (2)
#              18 PRECALL                  1
#              22 CALL                     1
#              32 POP_TOP
#              34 LOAD_CONST               3 (None)
#              36 RETURN_VALUE
#
# Disassembly of <code object circle_area at 0x7f0e3fc91d10, file "<string>", line 3>:
#   3           0 RESUME                   0
#
#   4           2 LOAD_GLOBAL              0 (pi)
#              14 LOAD_FAST                0 (r)
#              16 LOAD_CONST               1 (2)
#              18 BINARY_OP                8 (**)
#              22 BINARY_OP                5 (*)
#              26 RETURN_VALUE

# %%
code = """
def adder(n):
    def handler(x):
        return n+x
    return handler

add10 = adder(10)
print(add10(100))
print(add10.__closure__)
print(add10.__closure__[0].cell_contents)
add10.__closure__[0].cell_contents = 1000
print(add10(1))
"""
code = compile(code, filename="<string>", mode="exec")
print(code.co_consts)
print(code.co_names)
print(code.co_consts[1])
exec(code, globals(), {})
# dis.dis(code)
# Out:
# (<code object adder at 0x7f0e540d0e00, file "<string>", line 2>, 10, 100, 0, 1000, 1, None)
# ('adder', 'add10', 'print', '__closure__', 'cell_contents')
# 10
# 110
# (<cell at 0x7f0e540804f0: int object at 0x7f0e6a0f6028>,)
# 10
# 1001

# %%
code = """class Dog:
    def __init__(self, name):
        self.name = name
    def yelp(self):
        print(f'woof by {self.name}')
dog = Dog('dog')
dog.yelp()
def yelp2(self):
    print(f'woof 2 by {self.name}')
Dog.yelp2 = yelp2
dog.yelp2()"""
code = compile(code, filename="<string>", mode="exec")

print(code.co_consts)
print(code.co_names)
print(code.co_consts[0])
exec(code, globals(), {})
print(dis.dis(code))
# Out:
# (<code object Dog at 0x7f0e3fc924f0, file "<string>", line 1>, 'Dog', 'dog', <code object yelp2 at 0x7f0e3fd4a010, file "<string>", line 8>, None)
# ('Dog', 'dog', 'yelp', 'yelp2')
# <code object Dog at 0x7f0e3fc924f0, file "<string>", line 1>
# woof by dog
# woof 2 by dog
#   0           0 RESUME                   0
#
#   1           2 PUSH_NULL
#               4 LOAD_BUILD_CLASS
#               6 LOAD_CONST               0 (<code object Dog at 0x7f0e3fc924f0, file "<string>", line 1>)
#               8 MAKE_FUNCTION            0
#              10 LOAD_CONST               1 ('Dog')
#              12 PRECALL                  2
#              16 CALL                     2
#              26 STORE_NAME               0 (Dog)
#
#   6          28 PUSH_NULL
#              30 LOAD_NAME                0 (Dog)
#              32 LOAD_CONST               2 ('dog')
#              34 PRECALL                  1
#              38 CALL                     1
#              48 STORE_NAME               1 (dog)
#
#   7          50 LOAD_NAME                1 (dog)
#              52 LOAD_METHOD              2 (yelp)
#              74 PRECALL                  0
#              78 CALL                     0
#              88 POP_TOP
#
#   8          90 LOAD_CONST               3 (<code object yelp2 at 0x7f0e3fd4a010, file "<string>", line 8>)
#              92 MAKE_FUNCTION            0
#              94 STORE_NAME               3 (yelp2)
#
#  10          96 LOAD_NAME                3 (yelp2)
#              98 LOAD_NAME                0 (Dog)
#             100 STORE_ATTR               3 (yelp2)
#
#  11         110 LOAD_NAME                1 (dog)
#             112 LOAD_METHOD              3 (yelp2)
#             134 PRECALL                  0
#             138 CALL                     0
#             148 POP_TOP
#             150 LOAD_CONST               4 (None)
#             152 RETURN_VALUE
#
# Disassembly of <code object Dog at 0x7f0e3fc924f0, file "<string>", line 1>:
#   1           0 RESUME                   0
#               2 LOAD_NAME                0 (__name__)
#               4 STORE_NAME               1 (__module__)
#               6 LOAD_CONST               0 ('Dog')
#               8 STORE_NAME               2 (__qualname__)
#
#   2          10 LOAD_CONST               1 (<code object __init__ at 0x7f0e540d0e00, file "<string>", line 2>)
#              12 MAKE_FUNCTION            0
#              14 STORE_NAME               3 (__init__)
#
#   4          16 LOAD_CONST               2 (<code object yelp at 0x7f0e3fd49c50, file "<string>", line 4>)
#              18 MAKE_FUNCTION            0
#              20 STORE_NAME               4 (yelp)
#              22 LOAD_CONST               3 (None)
#              24 RETURN_VALUE
#
# Disassembly of <code object __init__ at 0x7f0e540d0e00, file "<string>", line 2>:
#   2           0 RESUME                   0
#
#   3           2 LOAD_FAST                1 (name)
#               4 LOAD_FAST                0 (self)
#               6 STORE_ATTR               0 (name)
#              16 LOAD_CONST               0 (None)
#              18 RETURN_VALUE
#
# Disassembly of <code object yelp at 0x7f0e3fd49c50, file "<string>", line 4>:
#   4           0 RESUME                   0
#
#   5           2 LOAD_GLOBAL              1 (NULL + print)
#              14 LOAD_CONST               1 ('woof by ')
#              16 LOAD_FAST                0 (self)
#              18 LOAD_ATTR                1 (name)
#              28 FORMAT_VALUE             0
#              30 BUILD_STRING             2
#              32 PRECALL                  1
#              36 CALL                     1
#              46 POP_TOP
#              48 LOAD_CONST               0 (None)
#              50 RETURN_VALUE
#
# Disassembly of <code object yelp2 at 0x7f0e3fd4a010, file "<string>", line 8>:
#   8           0 RESUME                   0
#
#   9           2 LOAD_GLOBAL              1 (NULL + print)
#              14 LOAD_CONST               1 ('woof 2 by ')
#              16 LOAD_FAST                0 (self)
#              18 LOAD_ATTR                1 (name)
#              28 FORMAT_VALUE             0
#              30 BUILD_STRING             2
#              32 PRECALL                  1
#              36 CALL                     1
#              46 POP_TOP
#              48 LOAD_CONST               0 (None)
#              50 RETURN_VALUE
# None

# %%
code = """class Animal:
    def run(self):
        print('running')

class Dog(Animal):
    def yelp(self):
        print('woof')
    def play(self):
        print('playing')

class Sleuth(Dog):
    def yelp(self):
        print('WOOF!')
    def hunt(self):
        print('hunting')

class SnifferDog(Dog):
    def search(self):
        print('searching')

class PoliceDog(Sleuth, SnifferDog):
    def patrol(self):
        print('patroling')

print(PoliceDog.__base__)
print(PoliceDog.__bases__)
print(PoliceDog.__mro__)
"""
code = compile(code, filename="<string>", mode="exec")
exec(code, globals(), {})
print(dis.dis(code))
# Out:
# <class '__main__.Sleuth'>
# (<class '__main__.Sleuth'>, <class '__main__.SnifferDog'>)
# (<class '__main__.PoliceDog'>, <class '__main__.Sleuth'>, <class '__main__.SnifferDog'>, <class '__main__.Dog'>, <class '__main__.Animal'>, <class 'object'>)
#   0           0 RESUME                   0
#
#   1           2 PUSH_NULL
#               4 LOAD_BUILD_CLASS
#               6 LOAD_CONST               0 (<code object Animal at 0x7f0e541a3500, file "<string>", line 1>)
#               8 MAKE_FUNCTION            0
#              10 LOAD_CONST               1 ('Animal')
#              12 PRECALL                  2
#              16 CALL                     2
#              26 STORE_NAME               0 (Animal)
#
#   5          28 PUSH_NULL
#              30 LOAD_BUILD_CLASS
#              32 LOAD_CONST               2 (<code object Dog at 0x7f0e3fc91fb0, file "<string>", line 5>)
#              34 MAKE_FUNCTION            0
#              36 LOAD_CONST               3 ('Dog')
#              38 LOAD_NAME                0 (Animal)
#              40 PRECALL                  3
#              44 CALL                     3
#              54 STORE_NAME               1 (Dog)
#
#  11          56 PUSH_NULL
#              58 LOAD_BUILD_CLASS
#              60 LOAD_CONST               4 (<code object Sleuth at 0x7f0e3fc92950, file "<string>", line 11>)
#              62 MAKE_FUNCTION            0
#              64 LOAD_CONST               5 ('Sleuth')
#              66 LOAD_NAME                1 (Dog)
#              68 PRECALL                  3
#              72 CALL                     3
#              82 STORE_NAME               2 (Sleuth)
#
#  17          84 PUSH_NULL
#              86 LOAD_BUILD_CLASS
#              88 LOAD_CONST               6 (<code object SnifferDog at 0x7f0e541a35d0, file "<string>", line 17>)
#              90 MAKE_FUNCTION            0
#              92 LOAD_CONST               7 ('SnifferDog')
#              94 LOAD_NAME                1 (Dog)
#              96 PRECALL                  3
#             100 CALL                     3
#             110 STORE_NAME               3 (SnifferDog)
#
#  21         112 PUSH_NULL
#             114 LOAD_BUILD_CLASS
#             116 LOAD_CONST               8 (<code object PoliceDog at 0x7f0e3fc957c0, file "<string>", line 21>)
#             118 MAKE_FUNCTION            0
#             120 LOAD_CONST               9 ('PoliceDog')
#             122 LOAD_NAME                2 (Sleuth)
#             124 LOAD_NAME                3 (SnifferDog)
#             126 PRECALL                  4
#             130 CALL                     4
#             140 STORE_NAME               4 (PoliceDog)
#
#  25         142 PUSH_NULL
#             144 LOAD_NAME                5 (print)
#             146 LOAD_NAME                4 (PoliceDog)
#             148 LOAD_ATTR                6 (__base__)
#             158 PRECALL                  1
#             162 CALL                     1
#             172 POP_TOP
#
#  26         174 PUSH_NULL
#             176 LOAD_NAME                5 (print)
#             178 LOAD_NAME                4 (PoliceDog)
#             180 LOAD_ATTR                7 (__bases__)
#             190 PRECALL                  1
#             194 CALL                     1
#             204 POP_TOP
#
#  27         206 PUSH_NULL
#             208 LOAD_NAME                5 (print)
#             210 LOAD_NAME                4 (PoliceDog)
#             212 LOAD_ATTR                8 (__mro__)
#             222 PRECALL                  1
#             226 CALL                     1
#             236 POP_TOP
#             238 LOAD_CONST              10 (None)
#             240 RETURN_VALUE
#
# Disassembly of <code object Animal at 0x7f0e541a3500, file "<string>", line 1>:
#   1           0 RESUME                   0
#               2 LOAD_NAME                0 (__name__)
#               4 STORE_NAME               1 (__module__)
#               6 LOAD_CONST               0 ('Animal')
#               8 STORE_NAME               2 (__qualname__)
#
#   2          10 LOAD_CONST               1 (<code object run at 0x7f0e3fc926b0, file "<string>", line 2>)
#              12 MAKE_FUNCTION            0
#              14 STORE_NAME               3 (run)
#              16 LOAD_CONST               2 (None)
#              18 RETURN_VALUE
#
# Disassembly of <code object run at 0x7f0e3fc926b0, file "<string>", line 2>:
#   2           0 RESUME                   0
#
#   3           2 LOAD_GLOBAL              1 (NULL + print)
#              14 LOAD_CONST               1 ('running')
#              16 PRECALL                  1
#              20 CALL                     1
#              30 POP_TOP
#              32 LOAD_CONST               0 (None)
#              34 RETURN_VALUE
#
# Disassembly of <code object Dog at 0x7f0e3fc91fb0, file "<string>", line 5>:
#   5           0 RESUME                   0
#               2 LOAD_NAME                0 (__name__)
#               4 STORE_NAME               1 (__module__)
#               6 LOAD_CONST               0 ('Dog')
#               8 STORE_NAME               2 (__qualname__)
#
#   6          10 LOAD_CONST               1 (<code object yelp at 0x7f0e3fc924f0, file "<string>", line 6>)
#              12 MAKE_FUNCTION            0
#              14 STORE_NAME               3 (yelp)
#
#   8          16 LOAD_CONST               2 (<code object play at 0x7f0e3fc91c30, file "<string>", line 8>)
#              18 MAKE_FUNCTION            0
#              20 STORE_NAME               4 (play)
#              22 LOAD_CONST               3 (None)
#              24 RETURN_VALUE
#
# Disassembly of <code object yelp at 0x7f0e3fc924f0, file "<string>", line 6>:
#   6           0 RESUME                   0
#
#   7           2 LOAD_GLOBAL              1 (NULL + print)
#              14 LOAD_CONST               1 ('woof')
#              16 PRECALL                  1
#              20 CALL                     1
#              30 POP_TOP
#              32 LOAD_CONST               0 (None)
#              34 RETURN_VALUE
#
# Disassembly of <code object play at 0x7f0e3fc91c30, file "<string>", line 8>:
#   8           0 RESUME                   0
#
#   9           2 LOAD_GLOBAL              1 (NULL + print)
#              14 LOAD_CONST               1 ('playing')
#              16 PRECALL                  1
#              20 CALL                     1
#              30 POP_TOP
#              32 LOAD_CONST               0 (None)
#              34 RETURN_VALUE
#
# Disassembly of <code object Sleuth at 0x7f0e3fc92950, file "<string>", line 11>:
#  11           0 RESUME                   0
#               2 LOAD_NAME                0 (__name__)
#               4 STORE_NAME               1 (__module__)
#               6 LOAD_CONST               0 ('Sleuth')
#               8 STORE_NAME               2 (__qualname__)
#
#  12          10 LOAD_CONST               1 (<code object yelp at 0x7f0e3fc91450, file "<string>", line 12>)
#              12 MAKE_FUNCTION            0
#              14 STORE_NAME               3 (yelp)
#
#  14          16 LOAD_CONST               2 (<code object hunt at 0x7f0e3fc91d10, file "<string>", line 14>)
#              18 MAKE_FUNCTION            0
#              20 STORE_NAME               4 (hunt)
#              22 LOAD_CONST               3 (None)
#              24 RETURN_VALUE
#
# Disassembly of <code object yelp at 0x7f0e3fc91450, file "<string>", line 12>:
#  12           0 RESUME                   0
#
#  13           2 LOAD_GLOBAL              1 (NULL + print)
#              14 LOAD_CONST               1 ('WOOF!')
#              16 PRECALL                  1
#              20 CALL                     1
#              30 POP_TOP
#              32 LOAD_CONST               0 (None)
#              34 RETURN_VALUE
#
# Disassembly of <code object hunt at 0x7f0e3fc91d10, file "<string>", line 14>:
#  14           0 RESUME                   0
#
#  15           2 LOAD_GLOBAL              1 (NULL + print)
#              14 LOAD_CONST               1 ('hunting')
#              16 PRECALL                  1
#              20 CALL                     1
#              30 POP_TOP
#              32 LOAD_CONST               0 (None)
#              34 RETURN_VALUE
#
# Disassembly of <code object SnifferDog at 0x7f0e541a35d0, file "<string>", line 17>:
#  17           0 RESUME                   0
#               2 LOAD_NAME                0 (__name__)
#               4 STORE_NAME               1 (__module__)
#               6 LOAD_CONST               0 ('SnifferDog')
#               8 STORE_NAME               2 (__qualname__)
#
#  18          10 LOAD_CONST               1 (<code object search at 0x7f0e3fc92410, file "<string>", line 18>)
#              12 MAKE_FUNCTION            0
#              14 STORE_NAME               3 (search)
#              16 LOAD_CONST               2 (None)
#              18 RETURN_VALUE
#
# Disassembly of <code object search at 0x7f0e3fc92410, file "<string>", line 18>:
#  18           0 RESUME                   0
#
#  19           2 LOAD_GLOBAL              1 (NULL + print)
#              14 LOAD_CONST               1 ('searching')
#              16 PRECALL                  1
#              20 CALL                     1
#              30 POP_TOP
#              32 LOAD_CONST               0 (None)
#              34 RETURN_VALUE
#
# Disassembly of <code object PoliceDog at 0x7f0e3fc957c0, file "<string>", line 21>:
#  21           0 RESUME                   0
#               2 LOAD_NAME                0 (__name__)
#               4 STORE_NAME               1 (__module__)
#               6 LOAD_CONST               0 ('PoliceDog')
#               8 STORE_NAME               2 (__qualname__)
#
#  22          10 LOAD_CONST               1 (<code object patrol at 0x7f0e3fc92250, file "<string>", line 22>)
#              12 MAKE_FUNCTION            0
#              14 STORE_NAME               3 (patrol)
#              16 LOAD_CONST               2 (None)
#              18 RETURN_VALUE
#
# Disassembly of <code object patrol at 0x7f0e3fc92250, file "<string>", line 22>:
#  22           0 RESUME                   0
#
#  23           2 LOAD_GLOBAL              1 (NULL + print)
#              14 LOAD_CONST               1 ('patroling')
#              16 PRECALL                  1
#              20 CALL                     1
#              30 POP_TOP
#              32 LOAD_CONST               0 (None)
#              34 RETURN_VALUE
# None

# %% [markdown]
# 一个类的C3超类线性化，是这个类加上它的这些父类的线性化和这些父类自身的列表的唯一性归并的总和。这些父类的列表作为给这个归并过程的最后实际参数，保持了这些直接父类的局部优先次序。
#
# 完成父类的线性化和父类列表的归并，选择这些列表的头部中第一个符合条件者，它不出现在任何这些列表的尾部（一个列表的除了第一个元素的所有元素）之中。注意一个良好头部，可以同时出现为多个列表的第一个元素，但是禁止它出现在任何其他地方。将选择的元素从以它作为头部的所有列表中移除，并将它填加到输出列表。重复选择并移除良好头部并扩展输出列表的过程，直到所有余下的列表被竭尽。如果在某一点上，因为所有余下列表的头部都出现在某个列表的尾部中，而没有良好头部可选，那么由于在继承层级中依赖的不一致次序，归并过程不能计算下去，故而最初类的线性化不存在。
#
# 计算一个类的线性化的一种朴素分治法，可以采用递归算法来为归并子例程找到父类的线性化。但是，这将在出现环状类层级时导致无限循环递归。为了检测这种环并打破无限递归，并重新利用前面计算的结果作为一种优化，递归调用应当通过缓存或记忆化的方式屏蔽重入以前的实际参数。
#
# 这个算法类似于找到拓扑次序。

# %%
class A:
    pass


class B(A):
    pass


class C(B):
    pass


class D(A):
    pass


class E(D):
    pass


class F(A):
    pass


class G(C, E, F):
    pass


# c3算法, 分叉前接近深度优先
print(G.__mro__)
# Out:
# (<class '__main__.G'>, <class '__main__.C'>, <class '__main__.B'>, <class '__main__.E'>, <class '__main__.D'>, <class '__main__.F'>, <class '__main__.A'>, <class 'object'>)

# %%
code = """import math
class Point:
    z = 0
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def distance(self):
        return math.sqrt(self.x*self.x + self.y*self.y)
p = Point(3, 4)
p = type.__call__(Point, 3, 4)

print(p.distance())
print(Point.distance(p))

bm = p.distance
print(bm())
print(bm.__func__(bm.__self__))

print(p.distance) # bound method
print(Point.distance.__get__(p)) # bound method
print(Point.distance) # function
"""
code = compile(code, filename="<string>", mode="exec")
exec(code, globals(), {})
print(dis.dis(code))
# Out:
# Exception ignored in: <function gc_callback at 0x7f0e3fb145e0>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fdbf060>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# Exception ignored in: <function gc_callback at 0x7f0e3fb145e0>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fdbf060>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fb145e0>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fdbf060>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 24
#       1 code = """import math
#       2 class Point:
#       3     z = 0
#    (...)     21 print(Point.distance) # function
#      22 """
#      23 code = compile(code, filename="<string>", mode="exec")
# ---> 24 exec(code, globals(), {})
#      25 print(dis.dis(code))
#
# File <string>:12
#
# File <string>:8, in distance(self)
#
# NameError: name 'math' is not defined
# Exception ignored in: <function gc_callback at 0x7f0e3fb145e0>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fdbf060>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fb145e0>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fdbf060>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>

# %% [markdown]
# ## magic funcs
# - ![](python_magic_funcs.png)

# %% [markdown]
# 对象属性的访问顺序：
#
# ①.实例属性
#
# ②.类属性
#
# ③.父类属性
#
# ④.__getattr__()方法

# %% [markdown]
# 属性查询优先级: 数据描述符优先级最高，对象属性空间次之，非数据描述符最低
#
#
# 　　　　① __getattribute__()， 无条件调用
#
# 　　　　② 数据描述符：由 ① 触发调用 （若人为的重载了该 __getattribute__() 方法，可能会调职无法调用描述符）
#
# 　　　　③ 实例对象的字典（若与描述符对象同名，会被覆盖哦）
#
# 　　　　④ 类的字典
#
# 　　　　⑤ 非数据描述符
#
# 　　　　⑥ 父类的字典
#
# 　　　　⑦ __getattr__() 方法

# %%
import re
class EmailField:

    EMAIL_MOD = re.compile('^[a-z0-9]+[\._]?[a-z0-9]+[@]\w+[.]\w{2,3}$')

    def __init__(self, attrname):
        self.attrname = attrname

    def __get__(self, instance, owner):
        return getattr(instance, self.attrname)

    def __set__(self, instance, value):
        if not self.EMAIL_MOD.match(value):
            raise Exception(f'email({value}) is not a valid email')

        setattr(instance, self.attrname, value)

    def __delete__(self, instance):
        raise Exception('can not delete email')

class User:

    email = EmailField(attrname='_email')

    def __init__(self, name, email):
        # 注意: 必须使用 name 作为实例属性, 否则无法触发 __set__ 方法
        self.name = name
        self.email = email


    @property
    def name(self):
        return self._name
    @name.setter
    def name(self, value):
        if len(value) <=5:
            raise ValueError(f'name({value}) must be at least 5 characters')
        self._name = value
    def __repr__(self):
        return "User(name='{}', email='{}')".format(self.name, self.email)

# 测试 name init 检查
try:
    user = User('Joh', 'admin@fasionchan.com')
except Exception as e:
    print(e)
# 测试 email init 检查
try:
    user = User('Johhhhh', 'adminaaa')
except Exception as e:
    print(e)

user = User('Johhhhh', 'admin@fasionchan.com')
# 测试 name setter 检查
try:
    # 可以检查, 必然报错
    user.name = "jj"
except Exception as e:
        print(e)

# 测试 email setter 检查
try:
    user.email = "adminaaa"
except Exception as e:
    print(e)

print(user)
# Out:
# name(Joh) must be at least 5 characters
# email(adminaaa) is not a valid email
# name(jj) must be at least 5 characters
# email(adminaaa) is not a valid email
# User(name='Johhhhh', email='admin@fasionchan.com')

# %%
import gc

def gc_callback(phase, info):
    if phase == "stop":
        print("本次GC回收了对象：")
        for obj in gc.garbage:
            print(obj, type(obj))

gc.callbacks.append(gc_callback)
gc.set_debug(gc.DEBUG_SAVEALL)

# 制造循环引用
class A:
    pass

a = A()
b = A()
a.b = b
b.a = a

del a
del b

gc.collect()
# Out:
# Exception ignored in: <function gc_callback at 0x7f0e3fb145e0>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fdbf060>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 2

# %%
class A:
    def __getattribute__(self, name):
        print(f"__getattribute__ {name}")
        return super().__getattribute__(name)
    def __getattr__(self, name):
        print(f"__getattr__ {name}")
        return 42

a = A()
print(a.x)                # 先打印 __getattribute__ x，再打印 __getattr__ x，最后输出 42
print(getattr(a, 'y'))    # 同上
print(getattr(a, 'z', 99))# 同上（因为 __getattr__ 返回42，只有在没定义__getattr__时才会用默认值）
# Out:
# Exception ignored in: <function gc_callback at 0x7f0e3fb145e0>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fdbf060>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fb145e0>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fdbf060>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fb145e0>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fdbf060>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fb145e0>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fdbf060>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# __getattribute__ x
# __getattr__ x
# 42
# __getattribute__ y
# __getattr__ y
# 42
# __getattribute__ z
# __getattr__ z
# 42
# __getattribute__ not_exist
# __getattr__ not_exist
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 15
#      13 print(getattr(a, 'y'))    # 同上
#      14 print(getattr(a, 'z', 99))# __getattribute__ z, __getattr__ z, 输出 42（因为 __getattr__ 返回42，只有在没定义__getattr__时才会用默认值）
# ---> 15 print(a.not_exist)       # __getattr__ not_exist, 抛出异常
#
# Cell In[28], line 8, in A.__getattr__(self, name)
#       6 print(f"__getattr__ {name}")
#       7 if name == 'not_exist':
# ----> 8     raise AttributeError()
#       9 return 42
#
# AttributeError:
# Exception ignored in: <function gc_callback at 0x7f0e3fb145e0>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fdbf060>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fb145e0>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fdbf060>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fb145e0>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fdbf060>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fb145e0>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# Exception ignored in: <function gc_callback at 0x7f0e3fdbf060>
# Traceback (most recent call last):
#   File "/tmp/ipykernel_3955117/172465593.py", line 7, in gc_callback
#   File "/tmp/ipykernel_3955117/3530700006.py", line 39, in __repr__
#   File "/tmp/ipykernel_3955117/3530700006.py", line 10, in __get__
# AttributeError: 'User' object has no attribute '_email'
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
# 本次GC回收了对象：
# <class '__main__.EmailField'> <class 'type'>
# (<class '__main__.EmailField'>, <class 'object'>) <class 'tuple'>
# <class '__main__.User'> <class 'type'>
# (<class '__main__.User'>, <class 'object'>) <class 'tuple'>
# Johnnnn@gmail.com is not a valid email <class 'Exception'>
# <traceback object at 0x7f0e55611100> <class 'traceback'>
# {'__module__': '__main__', 'EMAIL_MOD': re.compile('^[a-z0-9]+[\\._]?[a-z0-9]+[@]\\w+[.]\\w{2,3}$'), '__init__': <function EmailField.__init__ at 0x7f0e55fe99e0>, '__get__': <function EmailField.__get__ at 0x7f0e55fea8e0>, '__set__': <function EmailField.__set__ at 0x7f0e55feaac0>, '__delete__': <function EmailField.__delete__ at 0x7f0e55feaa20>, '__dict__': <attribute '__dict__' of 'EmailField' objects>, '__weakref__': <attribute '__weakref__' of 'EmailField' objects>, '__doc__': None} <class 'dict'>
# {'__module__': '__main__', 'email': <__main__.EmailField object at 0x7f0e55616d10>, '__init__': <function User.__init__ at 0x7f0e55feaca0>, 'name': <property object at 0x7f0e55fd1530>, '__repr__': <function User.__repr__ at 0x7f0e55feae80>, '__dict__': <attribute '__dict__' of 'User' objects>, '__weakref__': <attribute '__weakref__' of 'User' objects>, '__doc__': None} <class 'dict'>
# <traceback object at 0x7f0e55610ac0> <class 'traceback'>
# <function EmailField.__init__ at 0x7f0e55fe99e0> <class 'function'>
# <function EmailField.__get__ at 0x7f0e55fea8e0> <class 'function'>
# <function EmailField.__set__ at 0x7f0e55feaac0> <class 'function'>
# <function EmailField.__delete__ at 0x7f0e55feaa20> <class 'function'>
# <attribute '__dict__' of 'EmailField' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'EmailField' objects> <class 'getset_descriptor'>
# <__main__.EmailField object at 0x7f0e55616d10> <class '__main__.EmailField'>
# <function User.__init__ at 0x7f0e55feaca0> <class 'function'>
# <property object at 0x7f0e55fd1530> <class 'property'>
# <function User.__repr__ at 0x7f0e55feae80> <class 'function'>
# <attribute '__dict__' of 'User' objects> <class 'getset_descriptor'>
# <attribute '__weakref__' of 'User' objects> <class 'getset_descriptor'>
# <traceback object at 0x7f0e55610fc0> <class 'traceback'>
# <frame at 0x7f0e64072820, file '/tmp/ipykernel_3955117/3530700006.py', line 41, code <module>> <class 'frame'>
# <function User.name at 0x7f0e55fead40> <class 'function'>
# <function User.name at 0x7f0e55feade0> <class 'function'>
# <traceback object at 0x7f0e55613440> <class 'traceback'>
# <frame at 0x7f0e64072770, file '/tmp/ipykernel_3955117/3530700006.py', line 27, code __init__> <class 'frame'>
# <function <module> at 0x7f0e55fea7a0> <class 'function'>
# <frame at 0x7f0e5562bd30, file '/tmp/ipykernel_3955117/3530700006.py', line 14, code __set__> <class 'frame'>
